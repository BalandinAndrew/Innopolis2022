# %%
# Установка transformers
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.24.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.13.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.13.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.10.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.9.24)

# %%
import pandas as pd
from itertools import groupby

# %%
#import необходимых модулей

import pandas as pd
#from ludwig.api import LudwigModel
#from ludwig.visualize import learning_curves
import yaml
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from sklearn.utils.class_weight import compute_class_weight

import numpy as np
from datetime import datetime, timedelta

#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 10, 5
#графики в svg выглядят более четкими
import xgboost as xgb
from xgboost import plot_importance, plot_tree
import matplotlib.pyplot as plt

# %%
from matplotlib.pylab import float64
#Считывание данных в DataFrame 

train= pd.read_csv('train_geo.csv', sep=',', index_col=None)
test= pd.read_csv('test_geo.csv', sep=',', index_col=None)
train['Category']=0
train.loc[train['crop']==5,'Category']=1

# %%
train
# Out:
#                                                    .geo    id  area  \
# 0     {"type":"Polygon","coordinates":[[[42.49107269...  3536    20
# 1     {"type":"Polygon","coordinates":[[[50.25545110...  3739    45
# 2     {"type":"Polygon","coordinates":[[[37.99698998...  1294    28
# 3     {"type":"Polygon","coordinates":[[[44.72154181...  2859    19
# 4     {"type":"Polygon","coordinates":[[[34.77829934...  3685    33
# ...                                                 ...   ...   ...
# 4825  {"type":"Polygon","coordinates":[[[40.90052911...  3772    74
# 4826  {"type":"Polygon","coordinates":[[[40.00883381...  5191   109
# 4827  {"type":"Polygon","coordinates":[[[38.57789936...  5226    58
# 4828  {"type":"Polygon","coordinates":[[[53.31082730...  5390    14
# 4829  {"type":"Polygon","coordinates":[[[38.79371096...   860    75
#
#       nd_mean_2021-04-16  nd_mean_2021-04-19  nd_mean_2021-04-22  \
# 0               0.072846            0.261778            0.062981
# 1               0.332928            0.287182            0.097138
# 2               0.013679            0.007055            0.120804
# 3               0.105976            0.052500            0.001917
# 4               0.130885            0.063492            0.024416
# ...                  ...                 ...                 ...
# 4825            0.028770            0.038282            0.255329
# 4826            0.035939            0.030722            0.033869
# 4827            0.191255            0.063581            0.140111
# 4828            0.291399            0.221428            0.007247
# 4829            0.226925            0.043076            0.058611
#
#       nd_mean_2021-04-26  nd_mean_2021-04-28  nd_mean_2021-05-02  \
# 0               0.104442            0.021096            0.052202
# 1               0.152467            0.075484            0.000000
# 2               0.037839            0.259125            0.000000
# 3               0.011531            0.042316            0.000000
# 4               0.000000            0.150671            0.046717
# ...                  ...                 ...                 ...
# 4825            0.148166            0.225421            0.479483
# 4826            0.029646            0.318387            0.247905
# 4827            0.323984            0.000000            0.005056
# 4828            0.055074            0.057781            0.187749
# 4829            0.440539            0.120169            0.138846
#
#       nd_mean_2021-05-04  ...  nd_mean_2021-06-10  nd_mean_2021-07-05  \
# 0               0.158723  ...            0.000000            0.026784
# 1               0.140326  ...            0.000000            0.111148
# 2               0.037446  ...            0.130467            0.155225
# 3               0.000000  ...            0.000000            0.570928
# 4               0.254284  ...            0.073357            0.147842
# ...                  ...  ...                 ...                 ...
# 4825            0.071684  ...            0.139222            0.009041
# 4826            0.265180  ...            0.000000            0.187236
# 4827            0.092693  ...            0.000000            0.047572
# 4828            0.112403  ...            0.631304            0.694524
# 4829            0.020173  ...            0.010312            0.227649
#
#       nd_mean_2021-08-13  nd_mean_2021-08-27  nd_mean_2021-05-08  \
# 0               0.126832            0.614770            0.008857
# 1               0.174914            0.179612            0.113071
# 2               0.090607            0.054127            0.007437
# 3               0.073492            0.378900            0.327677
# 4               0.157676            0.012048            0.054223
# ...                  ...                 ...                 ...
# 4825            0.042483            0.022464            0.017705
# 4826            0.055721            0.044182            0.048316
# 4827            0.007225            0.145505            0.051215
# 4828            0.031836            0.453151            0.000000
# 4829            0.000000            0.096585            0.000000
#
#       nd_mean_2021-05-24  crop  Долгота_1   Широта_1  Category
# 0               0.081498     3  42.491073  51.414036         0
# 1               0.046997     4  50.255451  56.605392         0
# 2               0.219614     2  37.996990  53.835904         0
# 3               0.586523     5  44.721542  55.935339         1
# 4               0.017539     4  34.778299  52.907201         0
# ...                  ...   ...        ...        ...       ...
# 4825            0.148440     6  40.900529  50.905277         0
# 4826            0.041440     6  40.008834  51.798122         0
# 4827            0.079730     6  38.577899  53.192895         0
# 4828            0.006495     5  53.310827  55.183098         1
# 4829            0.011459     6  38.793711  52.727709         0
#
# [4830 rows x 77 columns]

# %%
test
# Out:
#                                                    .geo    id  area  \
# 0     {"type":"Polygon","coordinates":[[[35.96545926...   611    26
# 1     {"type":"Polygon","coordinates":[[[39.50520518...  6417    98
# 2     {"type":"Polygon","coordinates":[[[39.30105409...  3352    21
# 3     {"type":"Polygon","coordinates":[[[33.08144648...  4224    18
# 4     {"type":"Polygon","coordinates":[[[45.10231339...  3102    53
# ...                                                 ...   ...   ...
# 2066  {"type":"Polygon","coordinates":[[[38.68082436...  1743    18
# 2067  {"type":"Polygon","coordinates":[[[56.32489418...  3968    56
# 2068  {"type":"Polygon","coordinates":[[[37.89523772...  3809    92
# 2069  {"type":"Polygon","coordinates":[[[38.98573772...  5485    53
# 2070  {"type":"Polygon","coordinates":[[[37.66829628...  5899    33
#
#       nd_mean_2021-04-16  nd_mean_2021-04-19  nd_mean_2021-04-22  \
# 0               0.196691            0.000000            0.259303
# 1               0.091192            0.000000            0.125823
# 2               0.000000            0.033368            0.285057
# 3               0.111243            0.201012            0.000000
# 4               0.000000            0.234954            0.000000
# ...                  ...                 ...                 ...
# 2066            0.000000            0.017866            0.212560
# 2067            0.010670            0.105135            0.170843
# 2068            0.131978            0.058492            0.607262
# 2069            0.044726            0.093328            0.188758
# 2070            0.000000            0.003819            0.149500
#
#       nd_mean_2021-04-26  nd_mean_2021-04-28  nd_mean_2021-05-02  \
# 0               0.052522            0.133353            0.000000
# 1               0.000000            0.027636            0.433244
# 2               0.028275            0.089219            0.080082
# 3               0.000000            0.107940            0.000000
# 4               0.305964            0.268629            0.305554
# ...                  ...                 ...                 ...
# 2066            0.231169            0.012535            0.000000
# 2067            0.227927            0.000000            0.000000
# 2068            0.389112            0.061173            0.185756
# 2069            0.290000            0.178694            0.286592
# 2070            0.077181            0.161075            0.220894
#
#       nd_mean_2021-05-04  ...  nd_mean_2021-06-05  nd_mean_2021-06-10  \
# 0               0.058353  ...            0.188092            0.000000
# 1               0.344155  ...            0.067910            0.084682
# 2               0.220537  ...            0.044020            0.762353
# 3               0.213204  ...            0.114008            0.059159
# 4               0.131192  ...            0.209458            0.033658
# ...                  ...  ...                 ...                 ...
# 2066            0.103303  ...            0.018102            0.059161
# 2067            0.000000  ...            0.109647            0.744611
# 2068            0.000000  ...            0.000000            0.055619
# 2069            0.041403  ...            0.053296            0.200393
# 2070            0.125081  ...            0.098958            0.137899
#
#       nd_mean_2021-07-05  nd_mean_2021-08-13  nd_mean_2021-08-27  \
# 0               0.200005            0.714292            0.084197
# 1               0.025694            0.000000            0.108945
# 2               0.167975            0.037838            0.158279
# 3               0.058423            0.108990            0.237742
# 4               0.000000            0.048622            0.121296
# ...                  ...                 ...                 ...
# 2066            0.804364            0.077803            0.112885
# 2067            0.554205            0.572680            0.511447
# 2068            0.051682            0.008488            0.076760
# 2069            0.000000            0.040434            0.037837
# 2070            0.120050            0.051349            0.000000
#
#       nd_mean_2021-05-08  nd_mean_2021-05-24  crop  Долгота_1   Широта_1
# 0               0.157733            0.197326     ?  35.965459  52.383788
# 1               0.141947            0.000000     ?  39.505205  52.066982
# 2               0.073814            0.185710     ?  39.301054  49.945986
# 3               0.000000            0.000000     ?  33.081446  52.551563
# 4               0.010354            0.000000     ?  45.102313  55.371466
# ...                  ...                 ...   ...        ...        ...
# 2066            0.209859            0.269576     ?  38.680824  54.015096
# 2067            0.101374            0.119901     ?  56.324894  53.489044
# 2068            0.038590            0.086436     ?  37.895238  53.134645
# 2069            0.000000            0.165996     ?  38.985738  51.858673
# 2070            0.010335            0.143800     ?  37.668296  53.792407
#
# [2071 rows x 76 columns]

# %%
train.columns
# Out:
# Index(['.geo', 'id', 'area', 'nd_mean_2021-04-16', 'nd_mean_2021-04-19',
#        'nd_mean_2021-04-22', 'nd_mean_2021-04-26', 'nd_mean_2021-04-28',
#        'nd_mean_2021-05-02', 'nd_mean_2021-05-04', 'nd_mean_2021-05-07',
#        'nd_mean_2021-05-16', 'nd_mean_2021-05-17', 'nd_mean_2021-05-21',
#        'nd_mean_2021-05-26', 'nd_mean_2021-05-27', 'nd_mean_2021-05-29',
#        'nd_mean_2021-06-06', 'nd_mean_2021-06-09', 'nd_mean_2021-06-13',
#        'nd_mean_2021-06-16', 'nd_mean_2021-06-18', 'nd_mean_2021-06-19',
#        'nd_mean_2021-06-20', 'nd_mean_2021-06-22', 'nd_mean_2021-06-25',
#        'nd_mean_2021-06-27', 'nd_mean_2021-07-07', 'nd_mean_2021-07-08',
#        'nd_mean_2021-07-09', 'nd_mean_2021-07-13', 'nd_mean_2021-07-15',
#        'nd_mean_2021-07-17', 'nd_mean_2021-07-20', 'nd_mean_2021-07-26',
#        'nd_mean_2021-07-27', 'nd_mean_2021-07-29', 'nd_mean_2021-07-31',
#        'nd_mean_2021-08-07', 'nd_mean_2021-08-12', 'nd_mean_2021-04-15',
#        'nd_mean_2021-04-18', 'nd_mean_2021-04-25', 'nd_mean_2021-04-27',
#        'nd_mean_2021-04-29', 'nd_mean_2021-04-30', 'nd_mean_2021-06-07',
#        'nd_mean_2021-06-12', 'nd_mean_2021-06-28', 'nd_mean_2021-08-01',
#        'nd_mean_2021-08-11', 'nd_mean_2021-05-01', 'nd_mean_2021-05-03',
#        'nd_mean_2021-05-10', 'nd_mean_2021-05-15', 'nd_mean_2021-06-02',
#        'nd_mean_2021-06-03', 'nd_mean_2021-07-04', 'nd_mean_2021-08-10',
#        'nd_mean_2021-08-23', 'nd_mean_2021-04-20', 'nd_mean_2021-04-23',
#        'nd_mean_2021-05-09', 'nd_mean_2021-05-19', 'nd_mean_2021-05-20',
#        'nd_mean_2021-06-04', 'nd_mean_2021-06-05', 'nd_mean_2021-06-10',
#        'nd_mean_2021-07-05', 'nd_mean_2021-08-13', 'nd_mean_2021-08-27',
#        'nd_mean_2021-05-08', 'nd_mean_2021-05-24', 'crop', 'Долгота_1',
#        'Широта_1', 'Category'],
#       dtype='object')

# %%
column_names_to_train =['area', 'nd_mean_2021-04-16', 'nd_mean_2021-04-19',
       'nd_mean_2021-04-22', 'nd_mean_2021-04-26', 'nd_mean_2021-04-28',
       'nd_mean_2021-05-02', 'nd_mean_2021-05-04', 'nd_mean_2021-05-07',
       'nd_mean_2021-05-16', 'nd_mean_2021-05-17', 'nd_mean_2021-05-21',
       'nd_mean_2021-05-26', 'nd_mean_2021-05-27', 'nd_mean_2021-05-29',
       'nd_mean_2021-06-06', 'nd_mean_2021-06-09', 'nd_mean_2021-06-13',
       'nd_mean_2021-06-16', 'nd_mean_2021-06-18', 'nd_mean_2021-06-19',
       'nd_mean_2021-06-20', 'nd_mean_2021-06-22', 'nd_mean_2021-06-25',
       'nd_mean_2021-06-27', 'nd_mean_2021-07-07', 'nd_mean_2021-07-08',
       'nd_mean_2021-07-09', 'nd_mean_2021-07-13', 'nd_mean_2021-07-15',
       'nd_mean_2021-07-17', 'nd_mean_2021-07-20', 'nd_mean_2021-07-26',
       'nd_mean_2021-07-27', 'nd_mean_2021-07-29', 'nd_mean_2021-07-31',
       'nd_mean_2021-08-07', 'nd_mean_2021-08-12', 'nd_mean_2021-04-15',
       'nd_mean_2021-04-18', 'nd_mean_2021-04-25', 'nd_mean_2021-04-27',
       'nd_mean_2021-04-29', 'nd_mean_2021-04-30', 'nd_mean_2021-06-07',
       'nd_mean_2021-06-12', 'nd_mean_2021-06-28', 'nd_mean_2021-08-01',
       'nd_mean_2021-08-11', 'nd_mean_2021-05-01', 'nd_mean_2021-05-03',
       'nd_mean_2021-05-10', 'nd_mean_2021-05-15', 'nd_mean_2021-06-02',
       'nd_mean_2021-06-03', 'nd_mean_2021-07-04', 'nd_mean_2021-08-10',
       'nd_mean_2021-08-23', 'nd_mean_2021-04-20', 'nd_mean_2021-04-23',
       'nd_mean_2021-05-09', 'nd_mean_2021-05-19', 'nd_mean_2021-05-20',
       'nd_mean_2021-06-04', 'nd_mean_2021-06-05', 'nd_mean_2021-06-10',
       'nd_mean_2021-07-05', 'nd_mean_2021-08-13', 'nd_mean_2021-08-27',
       'nd_mean_2021-05-08', 'nd_mean_2021-05-24',  'Долгота_1',
       'Широта_1'
]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2071 entries, 0 to 2070
# Data columns (total 76 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   .geo                2071 non-null   object
#  1   id                  2071 non-null   int64
#  2   area                2071 non-null   int64
#  3   nd_mean_2021-04-16  2071 non-null   float64
#  4   nd_mean_2021-04-19  2071 non-null   float64
#  5   nd_mean_2021-04-22  2071 non-null   float64
#  6   nd_mean_2021-04-26  2071 non-null   float64
#  7   nd_mean_2021-04-28  2071 non-null   float64
#  8   nd_mean_2021-05-02  2071 non-null   float64
#  9   nd_mean_2021-05-04  2071 non-null   float64
#  10  nd_mean_2021-05-07  2071 non-null   float64
#  11  nd_mean_2021-05-16  2071 non-null   float64
#  12  nd_mean_2021-05-17  2071 non-null   float64
#  13  nd_mean_2021-05-21  2071 non-null   float64
#  14  nd_mean_2021-05-26  2071 non-null   float64
#  15  nd_mean_2021-05-27  2071 non-null   float64
#  16  nd_mean_2021-05-29  2071 non-null   float64
#  17  nd_mean_2021-06-06  2071 non-null   float64
#  18  nd_mean_2021-06-09  2071 non-null   float64
#  19  nd_mean_2021-06-13  2071 non-null   float64
#  20  nd_mean_2021-06-16  2071 non-null   float64
#  21  nd_mean_2021-06-18  2071 non-null   float64
#  22  nd_mean_2021-06-19  2071 non-null   float64
#  23  nd_mean_2021-06-20  2071 non-null   float64
#  24  nd_mean_2021-06-22  2071 non-null   float64
#  25  nd_mean_2021-06-25  2071 non-null   float64
#  26  nd_mean_2021-06-27  2071 non-null   float64
#  27  nd_mean_2021-07-07  2071 non-null   float64
#  28  nd_mean_2021-07-08  2071 non-null   float64
#  29  nd_mean_2021-07-09  2071 non-null   float64
#  30  nd_mean_2021-07-13  2071 non-null   float64
#  31  nd_mean_2021-07-15  2071 non-null   float64
#  32  nd_mean_2021-07-17  2071 non-null   float64
#  33  nd_mean_2021-07-20  2071 non-null   float64
#  34  nd_mean_2021-07-26  2071 non-null   float64
#  35  nd_mean_2021-07-27  2071 non-null   float64
#  36  nd_mean_2021-07-29  2071 non-null   float64
#  37  nd_mean_2021-07-31  2071 non-null   float64
#  38  nd_mean_2021-08-07  2071 non-null   float64
#  39  nd_mean_2021-08-12  2071 non-null   float64
#  40  nd_mean_2021-04-15  2071 non-null   float64
#  41  nd_mean_2021-04-18  2071 non-null   float64
#  42  nd_mean_2021-04-25  2071 non-null   float64
#  43  nd_mean_2021-04-27  2071 non-null   float64
#  44  nd_mean_2021-04-29  2071 non-null   float64
#  45  nd_mean_2021-04-30  2071 non-null   float64
#  46  nd_mean_2021-06-07  2071 non-null   float64
#  47  nd_mean_2021-06-12  2071 non-null   float64
#  48  nd_mean_2021-06-28  2071 non-null   float64
#  49  nd_mean_2021-08-01  2071 non-null   float64
#  50  nd_mean_2021-08-11  2071 non-null   float64
#  51  nd_mean_2021-05-01  2071 non-null   float64
#  52  nd_mean_2021-05-03  2071 non-null   float64
#  53  nd_mean_2021-05-10  2071 non-null   float64
#  54  nd_mean_2021-05-15  2071 non-null   float64
#  55  nd_mean_2021-06-02  2071 non-null   float64
#  56  nd_mean_2021-06-03  2071 non-null   float64
#  57  nd_mean_2021-07-04  2071 non-null   float64
#  58  nd_mean_2021-08-10  2071 non-null   float64
#  59  nd_mean_2021-08-23  2071 non-null   float64
#  60  nd_mean_2021-04-20  2071 non-null   float64
#  61  nd_mean_2021-04-23  2071 non-null   float64
#  62  nd_mean_2021-05-09  2071 non-null   float64
#  63  nd_mean_2021-05-19  2071 non-null   float64
#  64  nd_mean_2021-05-20  2071 non-null   float64
#  65  nd_mean_2021-06-04  2071 non-null   float64
#  66  nd_mean_2021-06-05  2071 non-null   float64
#  67  nd_mean_2021-06-10  2071 non-null   float64
#  68  nd_mean_2021-07-05  2071 non-null   float64
#  69  nd_mean_2021-08-13  2071 non-null   float64
#  70  nd_mean_2021-08-27  2071 non-null   float64
#  71  nd_mean_2021-05-08  2071 non-null   float64
#  72  nd_mean_2021-05-24  2071 non-null   float64
#  73  crop                2071 non-null   object
#  74  Долгота_1           2071 non-null   float64
#  75  Широта_1            2071 non-null   float64
# dtypes: float64(72), int64(2), object(2)
# memory usage: 1.2+ MB

# %%
# Разобьем трейн на 5 частей и сделаем 5 подвыборок для прогнозирования с переобучением
X_train_1=train.iloc[:950]
X_train_2=train.iloc[950:1900]
X_train_3=train.iloc[1900:2850]
X_train_4=train.iloc[2850:3800]
X_train_5=train.iloc[3800:]

X_train_podvib_1=pd.concat([X_train_2,X_train_3,X_train_4,X_train_5])
X_train_podvib_2=pd.concat([X_train_1,X_train_3,X_train_4,X_train_5])
X_train_podvib_3=pd.concat([X_train_1,X_train_2,X_train_4,X_train_5])
X_train_podvib_4=pd.concat([X_train_1,X_train_2,X_train_3,X_train_5])
X_train_podvib_5=pd.concat([X_train_1,X_train_2,X_train_3,X_train_4])

# %%
# Обучение разделению 
xgb_estimator = xgb.XGBClassifier(
    learning_rate =0.015,
     n_estimators=150,
     max_depth=16,
     min_child_weight=6,
     gamma=0,
     verbosity=2,
     subsample=0.8,
     colsample_bytree=0.8,
     objective= 'binary:logistic',#'multi:softmax',
     nthread=4,
     tree_method='gpu_hist',#,gpu_id=0, 'gpu_hist'
           #predictor='gpu_predictor',
    enable_categorical=True, 
    use_label_encoder=False,
     max_cat_to_onehot =50,
     eval_metric='merror',
     seed=9,
     feature_fraction=0.7,
     scale_pos_weight=1)

# %%
# %%time
# fit first model

xgb_estimator.fit(train[column_names_to_train], train['Category'])
# Out:
# CPU times: user 839 ms, sys: 18.4 ms, total: 858 ms
# Wall time: 859 ms
# XGBClassifier(colsample_bytree=0.8, enable_categorical=True,
#               eval_metric='merror', feature_fraction=0.7, learning_rate=0.015,
#               max_cat_to_onehot=50, max_depth=16, min_child_weight=6,
#               n_estimators=150, nthread=4, seed=9, subsample=0.8,
#               tree_method='gpu_hist', use_label_encoder=False, verbosity=2)

# %%
# Важность признаков XGBoost
# 
plt.rcParams["figure.figsize"] = (14, 25)
_ = plot_importance(xgb_estimator, height=0.9)

# %%
# Проверка на трейне
predictions = xgb_estimator.predict(train[column_names_to_train])

print("Значение метрики recall на трейне : ", recall_score(predictions, train['Category'], average='macro', zero_division=0))
# Out:
# Значение метрики recall на трейне :  0.9978960005054653

# %%
# проверка на тесте
predictions_fin= xgb_estimator.predict(test[column_names_to_train])
test['crop']=predictions_fin
test['crop'].value_counts()
# Out:
# 0    1746
# 1     325
# Name: crop, dtype: int64

# %%
test.loc[test['crop']==0,'crop']=0
test.loc[test['crop']==1,'crop']=5

# %%
test_itog=test[['id','crop']]
test_itog['crop']=test_itog['crop'].astype(int)
test_itog
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         id  crop
# 0      611     0
# 1     6417     0
# 2     3352     0
# 3     4224     0
# 4     3102     0
# ...    ...   ...
# 2066  1743     5
# 2067  3968     0
# 2068  3809     0
# 2069  5485     0
# 2070  5899     0
#
# [2071 rows x 2 columns]

# %%
test_itog.to_csv('Казань xgboost 5 9 150.csv', sep=',', index=None)
