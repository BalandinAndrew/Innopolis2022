# %%
# Установка transformers
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.24.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.13.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.13.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.10.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.9.24)

# %%
import pandas as pd
from itertools import groupby

# %%
#import необходимых модулей

import pandas as pd
#from ludwig.api import LudwigModel
#from ludwig.visualize import learning_curves
import yaml
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from sklearn.utils.class_weight import compute_class_weight

import numpy as np
from datetime import datetime, timedelta

#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 10, 5
#графики в svg выглядят более четкими
import xgboost as xgb
from xgboost import plot_importance, plot_tree
import matplotlib.pyplot as plt

# %%
#Считывание данных в DataFrame 

train= pd.read_csv('train_geo.csv', sep=',', index_col=None)
test= pd.read_csv('test_geo.csv', sep=',', index_col=None)
best= pd.read_csv('Казань мода проверка.csv', sep=',', index_col=None)
best.columns=['id','crop_best']

# %%
train
# Out:
#                                                    .geo    id  area  \
# 0     {"type":"Polygon","coordinates":[[[42.49107269...  3536    20
# 1     {"type":"Polygon","coordinates":[[[50.25545110...  3739    45
# 2     {"type":"Polygon","coordinates":[[[37.99698998...  1294    28
# 3     {"type":"Polygon","coordinates":[[[44.72154181...  2859    19
# 4     {"type":"Polygon","coordinates":[[[34.77829934...  3685    33
# ...                                                 ...   ...   ...
# 4825  {"type":"Polygon","coordinates":[[[40.90052911...  3772    74
# 4826  {"type":"Polygon","coordinates":[[[40.00883381...  5191   109
# 4827  {"type":"Polygon","coordinates":[[[38.57789936...  5226    58
# 4828  {"type":"Polygon","coordinates":[[[53.31082730...  5390    14
# 4829  {"type":"Polygon","coordinates":[[[38.79371096...   860    75
#
#       nd_mean_2021-04-16  nd_mean_2021-04-19  nd_mean_2021-04-22  \
# 0               0.072846            0.261778            0.062981
# 1               0.332928            0.287182            0.097138
# 2               0.013679            0.007055            0.120804
# 3               0.105976            0.052500            0.001917
# 4               0.130885            0.063492            0.024416
# ...                  ...                 ...                 ...
# 4825            0.028770            0.038282            0.255329
# 4826            0.035939            0.030722            0.033869
# 4827            0.191255            0.063581            0.140111
# 4828            0.291399            0.221428            0.007247
# 4829            0.226925            0.043076            0.058611
#
#       nd_mean_2021-04-26  nd_mean_2021-04-28  nd_mean_2021-05-02  \
# 0               0.104442            0.021096            0.052202
# 1               0.152467            0.075484            0.000000
# 2               0.037839            0.259125            0.000000
# 3               0.011531            0.042316            0.000000
# 4               0.000000            0.150671            0.046717
# ...                  ...                 ...                 ...
# 4825            0.148166            0.225421            0.479483
# 4826            0.029646            0.318387            0.247905
# 4827            0.323984            0.000000            0.005056
# 4828            0.055074            0.057781            0.187749
# 4829            0.440539            0.120169            0.138846
#
#       nd_mean_2021-05-04  ...  nd_mean_2021-06-05  nd_mean_2021-06-10  \
# 0               0.158723  ...            0.000000            0.000000
# 1               0.140326  ...            0.000000            0.000000
# 2               0.037446  ...            0.210496            0.130467
# 3               0.000000  ...            0.132886            0.000000
# 4               0.254284  ...            0.152003            0.073357
# ...                  ...  ...                 ...                 ...
# 4825            0.071684  ...            0.066882            0.139222
# 4826            0.265180  ...            0.131357            0.000000
# 4827            0.092693  ...            0.142930            0.000000
# 4828            0.112403  ...            0.085861            0.631304
# 4829            0.020173  ...            0.000000            0.010312
#
#       nd_mean_2021-07-05  nd_mean_2021-08-13  nd_mean_2021-08-27  \
# 0               0.026784            0.126832            0.614770
# 1               0.111148            0.174914            0.179612
# 2               0.155225            0.090607            0.054127
# 3               0.570928            0.073492            0.378900
# 4               0.147842            0.157676            0.012048
# ...                  ...                 ...                 ...
# 4825            0.009041            0.042483            0.022464
# 4826            0.187236            0.055721            0.044182
# 4827            0.047572            0.007225            0.145505
# 4828            0.694524            0.031836            0.453151
# 4829            0.227649            0.000000            0.096585
#
#       nd_mean_2021-05-08  nd_mean_2021-05-24  crop  Долгота_1   Широта_1
# 0               0.008857            0.081498     3  42.491073  51.414036
# 1               0.113071            0.046997     4  50.255451  56.605392
# 2               0.007437            0.219614     2  37.996990  53.835904
# 3               0.327677            0.586523     5  44.721542  55.935339
# 4               0.054223            0.017539     4  34.778299  52.907201
# ...                  ...                 ...   ...        ...        ...
# 4825            0.017705            0.148440     6  40.900529  50.905277
# 4826            0.048316            0.041440     6  40.008834  51.798122
# 4827            0.051215            0.079730     6  38.577899  53.192895
# 4828            0.000000            0.006495     5  53.310827  55.183098
# 4829            0.000000            0.011459     6  38.793711  52.727709
#
# [4830 rows x 76 columns]

# %%
train=train.loc[(train['crop']!=5)&(train['crop']!=3)]
train
#train['Category']=0
#train.loc[train['crop']==5,'Category']=1
# Out:
#                                                    .geo    id  area  \
# 1     {"type":"Polygon","coordinates":[[[50.25545110...  3739    45
# 2     {"type":"Polygon","coordinates":[[[37.99698998...  1294    28
# 4     {"type":"Polygon","coordinates":[[[34.77829934...  3685    33
# 6     {"type":"Polygon","coordinates":[[[32.91307525...  6889    22
# 7     {"type":"Polygon","coordinates":[[[54.47719421...  5703    83
# ...                                                 ...   ...   ...
# 4824  {"type":"Polygon","coordinates":[[[36.93335613...  3092   132
# 4825  {"type":"Polygon","coordinates":[[[40.90052911...  3772    74
# 4826  {"type":"Polygon","coordinates":[[[40.00883381...  5191   109
# 4827  {"type":"Polygon","coordinates":[[[38.57789936...  5226    58
# 4829  {"type":"Polygon","coordinates":[[[38.79371096...   860    75
#
#       nd_mean_2021-04-16  nd_mean_2021-04-19  nd_mean_2021-04-22  \
# 1               0.332928            0.287182            0.097138
# 2               0.013679            0.007055            0.120804
# 4               0.130885            0.063492            0.024416
# 6               0.065092            0.095285            0.317724
# 7               0.019472            0.250000            0.000000
# ...                  ...                 ...                 ...
# 4824            0.022992            0.028803            0.335140
# 4825            0.028770            0.038282            0.255329
# 4826            0.035939            0.030722            0.033869
# 4827            0.191255            0.063581            0.140111
# 4829            0.226925            0.043076            0.058611
#
#       nd_mean_2021-04-26  nd_mean_2021-04-28  nd_mean_2021-05-02  \
# 1               0.152467            0.075484            0.000000
# 2               0.037839            0.259125            0.000000
# 4               0.000000            0.150671            0.046717
# 6               0.092715            0.210422            0.000000
# 7               0.254601            0.000000            0.300878
# ...                  ...                 ...                 ...
# 4824            0.607104            0.000000            0.035375
# 4825            0.148166            0.225421            0.479483
# 4826            0.029646            0.318387            0.247905
# 4827            0.323984            0.000000            0.005056
# 4829            0.440539            0.120169            0.138846
#
#       nd_mean_2021-05-04  ...  nd_mean_2021-06-05  nd_mean_2021-06-10  \
# 1               0.140326  ...            0.000000            0.000000
# 2               0.037446  ...            0.210496            0.130467
# 4               0.254284  ...            0.152003            0.073357
# 6               0.103085  ...            0.032510            0.000000
# 7               0.153703  ...            0.230455            0.000000
# ...                  ...  ...                 ...                 ...
# 4824            0.372004  ...            0.000000            0.041140
# 4825            0.071684  ...            0.066882            0.139222
# 4826            0.265180  ...            0.131357            0.000000
# 4827            0.092693  ...            0.142930            0.000000
# 4829            0.020173  ...            0.000000            0.010312
#
#       nd_mean_2021-07-05  nd_mean_2021-08-13  nd_mean_2021-08-27  \
# 1               0.111148            0.174914            0.179612
# 2               0.155225            0.090607            0.054127
# 4               0.147842            0.157676            0.012048
# 6               0.095017            0.138907            0.030898
# 7               0.011134            0.006577            0.073889
# ...                  ...                 ...                 ...
# 4824            0.034454            0.061803            0.084490
# 4825            0.009041            0.042483            0.022464
# 4826            0.187236            0.055721            0.044182
# 4827            0.047572            0.007225            0.145505
# 4829            0.227649            0.000000            0.096585
#
#       nd_mean_2021-05-08  nd_mean_2021-05-24  crop  Долгота_1   Широта_1
# 1               0.113071            0.046997     4  50.255451  56.605392
# 2               0.007437            0.219614     2  37.996990  53.835904
# 4               0.054223            0.017539     4  34.778299  52.907201
# 6               0.006197            0.170735     4  32.913075  52.565627
# 7               0.132709            0.114116     6  54.477194  54.473085
# ...                  ...                 ...   ...        ...        ...
# 4824            0.056541            0.093624     2  36.933356  53.728441
# 4825            0.017705            0.148440     6  40.900529  50.905277
# 4826            0.048316            0.041440     6  40.008834  51.798122
# 4827            0.051215            0.079730     6  38.577899  53.192895
# 4829            0.000000            0.011459     6  38.793711  52.727709
#
# [3507 rows x 76 columns]

# %%
test
# Out:
#                                                    .geo    id  area  \
# 0     {"type":"Polygon","coordinates":[[[35.96545926...   611    26
# 1     {"type":"Polygon","coordinates":[[[39.50520518...  6417    98
# 2     {"type":"Polygon","coordinates":[[[39.30105409...  3352    21
# 3     {"type":"Polygon","coordinates":[[[33.08144648...  4224    18
# 4     {"type":"Polygon","coordinates":[[[45.10231339...  3102    53
# ...                                                 ...   ...   ...
# 2066  {"type":"Polygon","coordinates":[[[38.68082436...  1743    18
# 2067  {"type":"Polygon","coordinates":[[[56.32489418...  3968    56
# 2068  {"type":"Polygon","coordinates":[[[37.89523772...  3809    92
# 2069  {"type":"Polygon","coordinates":[[[38.98573772...  5485    53
# 2070  {"type":"Polygon","coordinates":[[[37.66829628...  5899    33
#
#       nd_mean_2021-04-16  nd_mean_2021-04-19  nd_mean_2021-04-22  \
# 0               0.196691            0.000000            0.259303
# 1               0.091192            0.000000            0.125823
# 2               0.000000            0.033368            0.285057
# 3               0.111243            0.201012            0.000000
# 4               0.000000            0.234954            0.000000
# ...                  ...                 ...                 ...
# 2066            0.000000            0.017866            0.212560
# 2067            0.010670            0.105135            0.170843
# 2068            0.131978            0.058492            0.607262
# 2069            0.044726            0.093328            0.188758
# 2070            0.000000            0.003819            0.149500
#
#       nd_mean_2021-04-26  nd_mean_2021-04-28  nd_mean_2021-05-02  \
# 0               0.052522            0.133353            0.000000
# 1               0.000000            0.027636            0.433244
# 2               0.028275            0.089219            0.080082
# 3               0.000000            0.107940            0.000000
# 4               0.305964            0.268629            0.305554
# ...                  ...                 ...                 ...
# 2066            0.231169            0.012535            0.000000
# 2067            0.227927            0.000000            0.000000
# 2068            0.389112            0.061173            0.185756
# 2069            0.290000            0.178694            0.286592
# 2070            0.077181            0.161075            0.220894
#
#       nd_mean_2021-05-04  ...  nd_mean_2021-06-05  nd_mean_2021-06-10  \
# 0               0.058353  ...            0.188092            0.000000
# 1               0.344155  ...            0.067910            0.084682
# 2               0.220537  ...            0.044020            0.762353
# 3               0.213204  ...            0.114008            0.059159
# 4               0.131192  ...            0.209458            0.033658
# ...                  ...  ...                 ...                 ...
# 2066            0.103303  ...            0.018102            0.059161
# 2067            0.000000  ...            0.109647            0.744611
# 2068            0.000000  ...            0.000000            0.055619
# 2069            0.041403  ...            0.053296            0.200393
# 2070            0.125081  ...            0.098958            0.137899
#
#       nd_mean_2021-07-05  nd_mean_2021-08-13  nd_mean_2021-08-27  \
# 0               0.200005            0.714292            0.084197
# 1               0.025694            0.000000            0.108945
# 2               0.167975            0.037838            0.158279
# 3               0.058423            0.108990            0.237742
# 4               0.000000            0.048622            0.121296
# ...                  ...                 ...                 ...
# 2066            0.804364            0.077803            0.112885
# 2067            0.554205            0.572680            0.511447
# 2068            0.051682            0.008488            0.076760
# 2069            0.000000            0.040434            0.037837
# 2070            0.120050            0.051349            0.000000
#
#       nd_mean_2021-05-08  nd_mean_2021-05-24  crop  Долгота_1   Широта_1
# 0               0.157733            0.197326     ?  35.965459  52.383788
# 1               0.141947            0.000000     ?  39.505205  52.066982
# 2               0.073814            0.185710     ?  39.301054  49.945986
# 3               0.000000            0.000000     ?  33.081446  52.551563
# 4               0.010354            0.000000     ?  45.102313  55.371466
# ...                  ...                 ...   ...        ...        ...
# 2066            0.209859            0.269576     ?  38.680824  54.015096
# 2067            0.101374            0.119901     ?  56.324894  53.489044
# 2068            0.038590            0.086436     ?  37.895238  53.134645
# 2069            0.000000            0.165996     ?  38.985738  51.858673
# 2070            0.010335            0.143800     ?  37.668296  53.792407
#
# [2071 rows x 76 columns]

# %%
train.columns
# Out:
# Index(['.geo', 'id', 'area', 'nd_mean_2021-04-16', 'nd_mean_2021-04-19',
#        'nd_mean_2021-04-22', 'nd_mean_2021-04-26', 'nd_mean_2021-04-28',
#        'nd_mean_2021-05-02', 'nd_mean_2021-05-04', 'nd_mean_2021-05-07',
#  32  nd_mean_2021-07-17  3507 non-null   float64
#  33  nd_mean_2021-07-20  3507 non-null   float64
#  34  nd_mean_2021-07-26  3507 non-null   float64
#  35  nd_mean_2021-07-27  3507 non-null   float64
#  36  nd_mean_2021-07-29  3507 non-null   float64
#  37  nd_mean_2021-07-31  3507 non-null   float64
#  38  nd_mean_2021-08-07  3507 non-null   float64
#  39  nd_mean_2021-08-12  3507 non-null   float64
#  40  nd_mean_2021-04-15  3507 non-null   float64
#  41  nd_mean_2021-04-18  3507 non-null   float64
#  42  nd_mean_2021-04-25  3507 non-null   float64
#  43  nd_mean_2021-04-27  3507 non-null   float64
#  44  nd_mean_2021-04-29  3507 non-null   float64
#  45  nd_mean_2021-04-30  3507 non-null   float64
#  46  nd_mean_2021-06-07  3507 non-null   float64
#  47  nd_mean_2021-06-12  3507 non-null   float64
#  48  nd_mean_2021-06-28  3507 non-null   float64
#  49  nd_mean_2021-08-01  3507 non-null   float64
#  50  nd_mean_2021-08-11  3507 non-null   float64
#  51  nd_mean_2021-05-01  3507 non-null   float64
#  52  nd_mean_2021-05-03  3507 non-null   float64
#  53  nd_mean_2021-05-10  3507 non-null   float64
#  54  nd_mean_2021-05-15  3507 non-null   float64
#  55  nd_mean_2021-06-02  3507 non-null   float64
#  56  nd_mean_2021-06-03  3507 non-null   float64
#  57  nd_mean_2021-07-04  3507 non-null   float64
#  58  nd_mean_2021-08-10  3507 non-null   float64
#  59  nd_mean_2021-08-23  3507 non-null   float64
#  60  nd_mean_2021-04-20  3507 non-null   float64
#  61  nd_mean_2021-04-23  3507 non-null   float64
#  62  nd_mean_2021-05-09  3507 non-null   float64
#  63  nd_mean_2021-05-19  3507 non-null   float64
#  64  nd_mean_2021-05-20  3507 non-null   float64
#  65  nd_mean_2021-06-04  3507 non-null   float64
#  66  nd_mean_2021-06-05  3507 non-null   float64
#  67  nd_mean_2021-06-10  3507 non-null   float64
#  68  nd_mean_2021-07-05  3507 non-null   float64
#  69  nd_mean_2021-08-13  3507 non-null   float64
#  70  nd_mean_2021-08-27  3507 non-null   float64
#  71  nd_mean_2021-05-08  3507 non-null   float64
#  72  nd_mean_2021-05-24  3507 non-null   float64
#  73  crop                3507 non-null   int64
#  74  Долгота_1           3507 non-null   float64
#  75  Широта_1            3507 non-null   float64
# dtypes: float64(72), int64(3), object(1)
# memory usage: 2.1+ MB

# %%
# Обучение разделению 
xgb_estimator = xgb.XGBClassifier(
    learning_rate =0.015,
     n_estimators=500,
     max_depth=16,
     min_child_weight=6,
     gamma=0,
     verbosity=2,
     subsample=0.8,
     colsample_bytree=0.8,
     objective= 'multi:softmax',#'binary:hinge',
     nthread=4,
     tree_method='gpu_hist',#,gpu_id=0, 'approx',#
           #predictor='gpu_predictor',
    enable_categorical=True, 
    use_label_encoder=False,
     max_cat_to_onehot =50,
     eval_metric='merror',
     seed=96,
     feature_fraction=0.7)
    #,scale_pos_weight=7)

# %%
# %%time
# fit first model

xgb_estimator.fit(train[column_names_to_train], train['crop'])
# Out:
# CPU times: user 13.7 s, sys: 207 ms, total: 13.9 s
# Wall time: 20.2 s
# XGBClassifier(colsample_bytree=0.8, enable_categorical=True,
#               eval_metric='merror', feature_fraction=0.7, learning_rate=0.015,
#               max_cat_to_onehot=50, max_depth=16, min_child_weight=6,
#               n_estimators=500, nthread=4, objective='multi:softprob', seed=96,
#               subsample=0.8, tree_method='gpu_hist', use_label_encoder=False,
#               verbosity=2)

# %%
# Важность признаков XGBoost
# 
plt.rcParams["figure.figsize"] = (14, 25)
_ = plot_importance(xgb_estimator, height=0.9)

# %%
# Проверка на трейне
predictions = xgb_estimator.predict(train[column_names_to_train])

print("Значение метрики recall на трейне : ", recall_score(predictions, train['crop'], average='macro', zero_division=0))
# Out:
# Значение метрики recall на трейне :  1.0

# %%
# проверка на тесте
predictions_fin= xgb_estimator.predict(test[column_names_to_train])
test['crop']=predictions_fin
test['crop'].value_counts()
# Out:
# 2    547
# 1    535
# 0    355
# 6    341
# 4    293
# Name: crop, dtype: int64

# %%
test_itog=test[['id','crop']]
test_itog['crop']=test_itog['crop'].astype(int)
test_itog
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         id  crop
# 0      611     1
# 1     6417     2
# 2     3352     4
# 3     4224     1
# 4     3102     6
# ...    ...   ...
# 2066  1743     6
# 2067  3968     1
# 2068  3809     2
# 2069  5485     6
# 2070  5899     0
#
# [2071 rows x 2 columns]

# %%
#test_itog.to_csv('Казань xgboost 5 binary.csv', sep=',', index=None)

# %%
test_summ=test_itog.merge(best,on='id',how='left')
test_summ
# Out:
#         id  crop  crop_best
# 0      611     1          3
# 1     6417     2          2
# 2     3352     4          3
# 3     4224     1          1
# 4     3102     6          6
# ...    ...   ...        ...
# 2066  1743     6          5
# 2067  3968     1          3
# 2068  3809     2          2
# 2069  5485     6          6
# 2070  5899     0          0
#
# [2071 rows x 3 columns]

# %%
test_summ.loc[(test_summ['crop_best']==5),'crop']=5
test_summ.loc[(test_summ['crop_best']==3),'crop']=3
test_summ.loc[test_summ['crop_best']!=test_summ['crop']]
# Out:
#         id  crop  crop_best
# 61    1297     6          4
# 99    6848     0          6
# 267   4915     4          0
# 328   5101     2          6
# 447   2118     6          0
# 521   6651     4          6
# 594   4086     4          2
# 633   5814     4          6
# 715   3123     2          4
# 946   3176     0          2
# 1063   216     2          4
# 1107  6602     6          0
# 1332  1657     6          4
# 1394  4464     4          0
# 1406  2183     4          0
# 1454  3734     6          2
# 1648  3927     6          0
# 1731   877     2          0
# 1837  6856     0          6
# 1847  3235     1          6
# 1952  1496     0          6
# 2006  6094     0          1

# %%
test_summ['crop'].value_counts()
# Out:
# 5    326
# 6    312
# 3    309
# 2    297
# 1    288
# 0    272
# 4    267
# Name: crop, dtype: int64

# %%
test_summ=test_summ[['id','crop']]

# %%
test_summ.to_csv('Казань xgboost 5 и 3 gpu_hist.csv', sep=',', index=None)
